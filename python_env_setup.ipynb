# %% [markdown]
# ### Libraries for Machine Learning
# - General
#     - numpy
#     - pandas
#     - matplotlib
#     - opencv-python
#     - scipy
# - ML frameworks
#     - Pytorch
#     - scikit-learn
#     - transformers
# - Storage
#     - sqlitedict
# - Logging
#     - wandb
#     - tensorboard
#     - terminaltables

# %%
# General: Pandas, numpy, matplotlib, opencv
# !pip install numpy pandas matplotlib opencv-python scipy

# ML frameworks: pytroch (https://pytorch.org/), scikit-learn, transformers
# !pip install torch torchvision torchaudio scikit-learn transformers

# storage
# !pip install sqlitedict 

# logging libraries: wandb
# !pip install wandb tensorboard terminaltables
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 1.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 1.0 MB/s eta 0:00:00m eta 0:00:010:00:010m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.4/46.4 MB 1.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 MB 1.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#   Using cached pytz-2022.2.1-py2.py3-none-any.whl (500 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.3/241.3 kB 1.2 MB/s eta 0:00:000:00:010:00:01:01
# ...
#   Using cached packaging-21.3-py3-none-any.whl (40 kB)
# ...
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 960.0/960.0 kB 1.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 9.6 MB/s eta 0:00:000m eta 0:00:010:00:01
# ...
